# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
sns.set_theme(style="darkgrid")

# %%
df= pd.read_csv('pass.csv')
print("Dataset:")
print(df.head())
plt.figure(figsize=(8,5))
plt.scatter(df['hours'], df['pass'], c=df['pass'], cmap='magma', edgecolors='k')
plt.xlabel('hours studied')
plt.ylabel('pass (1) / fail (0)')
plt.title('Hours vs Result')
plt.show()
# Out:
# Dataset:
#    hours  pass
# 0    0.5     0
# 1    1.0     0
# 2    1.5     0
# 3    2.0     0
# 4    2.5     0

# %%
x=df[["hours"]]
y=df[["pass"]]
model=LogisticRegression()
model.fit(x,y)
print("model trained successfully")
# Out:
# model trained successfully
# c:\Users\GALAXY BOOK4\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['hours'],df['pass'],c=df['pass'],cmap='bwr',label='Data Points')
x_test_range=np.linspace(0,10,100).reshape(-1,1)
y_prob_range=model.predict_proba(x_test_range)[:,1]
plt.plot(x_test_range,y_prob_range,color='green',linewidth=3,label='Logistic Curve')
plt.axhline(y=0.5,color='gray',linestyle='--',label='Decision Boundary(0.5)')
plt.xlabel('hours studied')
plt.ylabel('probability of passings')
plt.title('Logistic Regression Sigmoid Curve')
plt.legend()
plt.show()
# Out:
# c:\Users\GALAXY BOOK4\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
try:
    # Get user input
    user_hours = float(input("Enter study hours (0-10): "))

    # Prepare input for model
    X_user = np.array([[user_hours]])

    # Make prediction
    prediction = model.predict(X_user)[0]
    probability = model.predict_proba(X_user)[0][1]

    # Output result
    if prediction == 1:
        print(f"\nResult: PASS ")
        print(f"Confidence: {probability*100:.2f}%")
    else:
        print(f"\nResult: FAIL ")
        print(f"Confidence: {(1-probability)*100:.2f}%")

except ValueError:
    print("Invalid input. Please enter a numerical value for hours.")
# Out:
# Result: FAIL
# Confidence: 59.21%
# c:\Users\GALAXY BOOK4\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\GALAXY BOOK4\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
